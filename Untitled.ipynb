# %% [markdown]
# <a href="https://colab.research.google.com/github/ky000020/Pemrograman-Dasar/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata saya

nama= "Hengky Ryanto Sihombing"
umur= 20
jurusan= "RPE"
semeseter= 3
matakuliah='Pemegroman Dasar'
status_lulus= False

"""
print (nama)
print (umur)
print (jurusan)
print (matakuliah)
print (status_lulus)
"""
# Out:
# '\nprint (nama)\nprint (umur)\npinrt (jurusan)\nprint (matakuliah)\nprint (status_lulus)\n'

# %%
# Biodata saya

nama= "Hengky Ryanto Sihombing"
umur= "20"
jurusan= "Elektro"
prodi= "TRPE"
semester= 3
matakuliah='Pemegroman Dasar'
status_lulus= False
hoby= "Futsal"
makanan_kesukaan= "Nasi goreng"
hewan_keseukaan= "Ular"
musik_kesukaan= "Film favorit by sheila on 7"
tamatan_sma= "SMA N 1 BATAM"
lulus_sma_tahun= 2025
"""
print (nama)
print (umur)
print (jurusan)
print (prodi)
print (matakuliah)
print (status_lulus)
print (hoby)
print (makanan_kesukaan)
print (hewan_kesukaan)
print (musik_kesukaan)
Print (tamatan_sma)
"""
# Out:
# '\nprint (nama)\nprint (umur)\nprint (jurusan)\nprint (prodi)\nprint (matakuliah)\nprint (status_lulus)\nprint (hoby)\nprint (makanan_kesukaan)\nprint (hewan_kesukaan)\nprint (musik_kesukaan)\nPrint (tamatan_sma)\n'
