# %% [markdown]
# <a href="https://colab.research.google.com/github/ky000020/Pemrograman-Dasar/blob/main/Minggu%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 12
y = 8
z = x+y

print(z)

x = 11
y = "12"


print(type(x))
print(type(y))



mahasiswa = ["KY", 4232501055, False, 160.0]
print(mahasiswa)
mahasiswa[2]
# Out:
# 20
# <class 'int'>
# <class 'str'>
# ['KY', 4232501055, False, 160.0]
# False

# %%
# Latihan 1

tegangan = 18
arus = 6
jenis_sel = "Monocrystalline"

print(tegangan)
print(arus)
print(jenis_sel)
# Out:
# 18
# 6
# Monocrystalline

# %%
# Latihan 2

tegangan = 18          # int
daya = 108.5           # float
aktif = True           # bool
jenis_komponen = "Panel Surya"  # str

print(tegangan, type(tegangan))
print(daya, type(daya))
print(aktif, type(aktif))
print(jenis_komponen, type(jenis_komponen))
# Out:
# 18 <class 'int'>
# 108.5 <class 'float'>
# True <class 'bool'>
# Panel Surya <class 'str'>

# %%
# Latihan 3

nama_unit = "PLTS Nunukan"
jumlah_panel = 240
tegangan_keluaran = 48.5
sedang_beroperasi = True

print(nama_unit, type(nama_unit))
print(jumlah_panel, type(jumlah_panel))
print(tegangan_keluaran, type(tegangan_keluaran))
print(sedang_beroperasi, type(sedang_beroperasi))
# Out:
# PLTS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>

# %%
# Latihan 4


Tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

#a
print("pembaca pertama:", Tegangan_harian[0])
print("pemabaca terakhir", Tegangan_harian[5])

#b
Tegangan_harian.append(222.0)

#c
print("Tegangan_harian:", len(Tegangan_harian))
# Out:
# pembaca pertama: 217.5
# pemabaca terakhir 216.9
# Tegangan_harian: 7

# %%
# Latihan 5
motor_listrik = {
    "nama": "motor induksi 3 fasa",
    "daya_Kw": 5.5,
    "tegangan_V": 380,
    "rpm": 1450

}
print("nama motor", motor_listrik["nama"])

motor_listrik["rpm"]= 1500

print(motor_listrik)
# Out:
# nama motor motor induksi 3 fasa
# {'nama': 'motor induksi 3 fasa', 'daya_Kw': 5.5, 'tegangan_V': 380, 'rpm': 1500}

# %%
# Latihan 6
unit_pembangkit = [
{"PLTU Bahagia": "unit-1", "kapasitas_Mw": 100, "status": "operasi"},
{"PLTD Sedih": "unit-2", "kapasitas_Mw": 150, "status": "operasi"},
{"PLTD Enak": "unit-3", "kapasitas_Mw": 80, "status": "pemeliharaan"}]

#cetak unit kedua
print("unit-2:", unit_pembangkit[1]["PLTD Sedih"])

#ubah status salah satu unit
unit_pembangkit[2]["status"] ="operasi"

#tambahan satu unit baru
unit_baru = {
    "nama": "PLTS Hemat",
    "kapasitas_Mw": 90,
    "status": "operasi"}

unit_pembangkit.append(unit_baru)

print("\nseluruh data unit pembangkit:")
print(unit_pembangkit)
# Out:
# unit-2: unit-2
#
# seluruh data unit pembangkit:
# [{'PLTU Bahagia': 'unit-1', 'kapasitas_Mw': 100, 'status': 'operasi'}, {'PLTD Sedih': 'unit-2', 'kapasitas_Mw': 150, 'status': 'operasi'}, {'PLTD Enak': 'unit-3', 'kapasitas_Mw': 80, 'status': 'operasi'}, {'nama': 'PLTS Hemat', 'kapasitas_Mw': 90, 'status': 'operasi'}]
